# %% [markdown]
# # Python

# %% [raw]
# -- Python is a high level interpreted programming language
# -- It is easy to learn
# -- It has large no.of libraries which helps us to do complex work with very little code
# -- It is used in web development, DS, AI, Automation, Apps, Games - almost everyweher

# %% [markdown]
# # Why Python?

# %% [raw]
# Becoz python reduces our effort we can finish a task in 5 lines that may take 20 lines in other language like C, C++ or Java

# %% [markdown]
# # Basic Concepts To Learn

# %% [markdown]
# # Identifier

# %% [raw]
# Identifier is an any name we give in python
# ex: variable name, function name, class name, etc..
# realtime ex: Boy & Girl (names based on gender)
#
# Rules:
# 1. Must start with A-Z, a-z, _ (underscore)
# 2. Cannot start with numbers
# 3. Cannot contain special symbols like : @, #, $, %, &, *, etc...
# 4. Cannot use Keywords as identifiers
#
# test:

# %% [markdown]
# # Keyword

# %% [raw]
# Keywords are reserved words in python
# They already have a meaning, so we cannot use them as identifiers
#
# ex: if,for,while,class,return,break,True,False,etc..
#
# Python uses these words internally, so we are not allowed to change their purpose

# %% [markdown]
# # Variable

# %% [raw]
# Variable is a container where we store a value
#
# Ex: a = 10
# 10 is a value stored inside a varaible called 'a'
#
# ex2: Think of a box with a label

# %% [markdown]
# # Comments

# %% [raw]
# Comments are notes written for humans, not the computer
# -- python will ignore comments
# -- we use them to explain code
#
# Types of comments
# 1. Single line comments
# -- Starts with #
#
# ex: # hi hello
#
# 2. Multi line comments
# -- uses triple quotes '''___''' or """___"""
#
# ex: """ Good morning """
#     ''' Good evening '''
# These are not real comments, But python treats them as strings not used anywhere
#
#
# Why ?
# -- To explain code
# -- For documentation
# -- For disabling code temporarily

# %% [markdown]
# # Statement

# %% [raw]
# Statement is a complete instruction given to python
#
# --- Types of stmts ---
#
# 1. single line stmt
# ex: a = 10+20+30   #SLS
#     a
#
# 2. Multiple line stmt
# if stmt is too long, we can break it into multiple lines using a backslash (\) -- tells python that this line continues below, don't end the stmt yet (joins all the lines into one single line)
# ex: b = 10+20+30\
#         +40+50+\
#         60+70+80
#     b
#
# 3. Assignment Statement
# Used to store values in variables
# ex:
# name = "Keerty"
# dept = "DS"
#
# 4. Print Statement
# Used to display output.
# ex:
# print("Welcome to Python")
#
# 5. Conditional Statement
# Used for decision making.
# ex:
# if age >= 18:
#    print("Eligible to vote")
#
# 6.Loop Statement
# Used to repeat actions.
# ex:
# for i in range(3):
#    print(i)

# %% [markdown]
# # Variable Assignment

# %% [raw]
# Variable assignment means storing a value inside a variable using '=' symbol
# ex: x = 10
#     y = 5
#
# Here, X is a variable
#       = is an assignment operator
#       10 is a value assigned

# %% [markdown]
# # Multiple Variable Assignment

# %% [raw]
# Python allows assigning values in different styles
# 1. Multiple variables, Multiple values
# ex: a,b,c = 10,20,30
#     print(a,b,c)
# each variable gets the value in order
#
# 2. Multiple variables, same value
# -- all variables get the same value
# ex: x=y=z=100
#     print(x,y,z)
#
# 3. Swapping variable (without Temp variable)
# -- python special feature
# -- no need of third variable like in other language (c,c++,java)
# ex: a = 5
#     b = 10
#     a,b = b,a
#     print(a,b)  # 10,5

# %% [markdown]
# # Data Types

# %% [raw]
# what type of value a variable is holding
#
# Types of Data Types
# 1. Numeric -- Numbers
# a. Integer (whole nos -- no decimals)
# -- defined as int
# ex: a = 19
# b. Float (nos with decimal)
# -- defined as float
# ex: a = 9.03
#
# 2. Boolean -- stores Truth Values (True/False)
# -- defined as bool
# ex: b = True
#     c = False
#
# 3. String -- a seq of characters put inside a single/double/triple quotes
# -- defined as str
# ex : name = 'Keerty'
#      dept = "DS"
#      city = '''Hyd'''

# %% [markdown]
# # String Indexing

# %% [raw]
# In String each character has a position (index)
# -- String indexing means accessing a character by using its position
#
# Types of SI
# 1. Positive SI (L to R) -- starts from 0
# 2. Negative SI (R to L) -- starts from -1
#
# syntax : Var_name[index no.]
#
# ex: s = 'Hello Python'
#     s[5] , s[-3], s[0]

# %% [markdown]
# # String Slicing

# %% [raw]
# String Slicing
# means taking a piece of string
# -- here we're aiming to cut the string
#
# Syntax : var_name[start:stop:step]
#                   included : excluded(stop-1) : jumpvalue (default = 1)
#
# ex: s = "Python Programming"
#
# s[0:6] #=Python
# s[0:15:2] #every 2nd char
# s[::-1] # reverse string

# %% [markdown]
# # TYPE CASTING

# %% [raw]
# simply means changing/converting one datatype into another datatype
#
# Types of TC
# 1. Automatic TC (Implicit)
# -- Python itself converts the datatype when needed
# -- python interpreter based on some hierarchy
# Float -- int -- bool
# -- stings are not involved in ATC
#
# ex: a = 2+3.4+True  # True = 1
#     a  # float value u will get
#
# 2. Forced TC (Explict)/ Manual TC
# -- we use python fns (Built-in classes) to convert the value into our required DT
# The Main Fns are :
# a. int() -- convert any type of data into Integer
# b. float() -- convert any type of data into Float
# c. str() -- convert any type of data into String
# d. bool() -- convert any type of data into Boolean
#
# ex: int -- float
#     a = 10
#     a
#     b = float(a)
#     b

# %% [markdown]
# # Operators

# %% [raw]
# are ntg but special symbols that help python perform actions on variables/values
#
# 1. ARTHIMETIC OPERATORS
# -- these are the basic math operators we use for calculations
# a. addition +
# b. sub -
# c. mul *
# d. div /
# e. floor div // (gives only the whole no.)
# f. modulus % (gives reminder)
# g. exponent ** (power)
#
# ex: a = 10
#     b = 3
#     a+b , a-b, a*b, a/b, a%b, a**b
#
# 2. COMPARISION OPERATOR
# -- these operators compares 2 values/variables and returns True/False as o/p
# 1. == equal to
# 2. != not equal to
# 3. > greater than
# 4. < less than
# 5. >= greater than or equal to
# 6. <= less than or equal to
#
# 3. LOGICAL OPERATORS
# these helps us to compare multiple conditions at a time
# -- it returns True/False
# 1. AND -- TRUE only if both the conditions are TRUE
# 2. OR -- TRUE even if any 1 condition is TRUE
# 3. NOT -- reverse the output

# %% [markdown]
# # Conditional Statements

# %% [raw]
# # Conditional Statements
# Operators only compare/calculate values
# but i want to make a decision based on those comparisions
# for that we use these conditional stmts
#
# Types of Conditional Stmts
# 1. If stmt
# -- Executes a block of code only if the condition is TRUE
# syntax: if condition:
#            stmt
# -- indentation : 1Tab space/4 spaces
#
# ex: age = 20
#     if age>= 18:
#         print("Eligible")
#
# ex2: num = 10
#      if num>0:
#          print("+ve no.")
#
# ex3: marks = 95
#      if marks == 95:
#          print("Great Score")

# %% [raw]
# 2. if else stmt
# -- if works only when the condition is TRUE but what if the condition is false?
# we need an alternative path -- that is else
#
# syntax:
# if condition:
#     stmt
# else:
#     stmt
#
# ex:
# num = 7
# if num % 2 == 0:
#     print("Even")
# else:
#     print("Odd")
#
# ex2:
# temp = 32
# if temp > 30:
#     print("Hotday")
# else:
#     print("Nrml day")
#
# ex3:
# a = 10
# b = 2
# if a>b:
#     print("A is big")
# else:
#     print("B is big")

# %% [raw]
# input() fn :
# -- Till now we used fixed values but in real programs
# we want users to enter values, that's where input() comes in
# -- by default it returns string
#
# syntax:
# var = input("message")
#
# ex:
# name = input("Enter ur name:")
# print("Hello",name)
#
# ex1:
# age = int(input("Enter ur age:"))
# print("I'm",age,"years old")

# %% [raw]
# 3. elif stmt
# -- if else gives 2 choices but sometimes we need multiple choices
# not just True/False but many conditions
# that's where elif helps
#
# Syntax:
# if condition1:
#     stmt
# elif cond2:
#     stmt
# elif cond3:
#     stmt
# else:
#     stmt
#
# ex:
# marks = int(input("Enter a number:"))
# if marks >= 90:
#     print("A grade")
# elif marks >= 75:
#     print("B grade")
# elif marks >= 60:
#     print("C grade")
# else:
#     print("D grade")
#
# ex2:
# age = 45
# if age < 13:
#     print("Child")
# elif age<20:
#     print("Teen")
# elif age<60:
#     print("Adult")
# else:
#     print("Senior")
#
# ex3:
# day = 3
# if day == 1:
#     print("Monday")
# elif day == 2:
#     print("Tuesday")
# elif day == 7:
#     print("Sunday")
# else:
#     Print("Invalid")

# %% [raw]
# 4. Nested if stmt
# -- sometimes one condition depends on another then we use it
# -- nested if is ntg but a decision inside another decision
#
# syntax:
# if cond1:
#     if cond2:
#         stmt
#     else:
#         stmt
# else:
#     stmt
#
# ex:
# num = 12
# if num>0:
#     if num%2==0:
#         print("+ve even")
#     else:
#         print("+ve odd")
# else:
#     print("-ve number")
#
#
#
# ex2:
# num = int(input("Enter a num"))
# if num>0:
#     if num%2==0:
#         print("+ve even")
#     else:
#         print("+ve odd")
# if num<0:
#     if num%2 == 0:
#         print("-ve even")
#     else:
#         print("-ve odd")
#
# ex3:
# score = 80
# if score >= 50:
#     if score >= 90:
#         print("Excellent")
#     else:
#         print("Good")
# else:
#     print("Fail")

# %% [markdown]
# # Data Structures

# %% [raw]
# Till now we worked with single value like a=10 , age = 20, name ="Keerty"
# but in real life, we work with multiple values together like
# -- list of students
# -- marks of one student
# -- prices of items
#
# so for that purpose we use these Data Structures
# -- DS helps us To store multiple values in a single variable
#
# Types of DS
# 1. List
# 2. Tuple
# 3. Set
# 4. Dictionary

# %% [markdown]
# # List

# %% [raw]
# List is a bag/container/place where we store many values together in one variable
# -- stored in []
#
# syntax: listname = [value1,value2,value3,..valuen]
# ex: a = [1,2,3,4]
#
# properties:
# 1. Ordered : items have fixed positions
# 2. Mutable : we can modify values (changable)
# 3. Heterogeneous : can store diff datatypes (int,str,bool,float,etc..)
# 4. Allow duplicates : same value can repeat
# 5. Indexed : Each item has a number (position)

# %% [markdown]
# # List Indexing

# %% [raw]
# Each item in a list has a position number called INDEX
# -- index always starts from '0' (+ve)
# -- index always starts from '-1' (-ve)
#
# syntax : listname[index]
#
# ex:
# F = ["apple","banana","mango"]
# F[0]  # apple
# F[-2]  # banana

# %% [markdown]
# # List slicing

# %%
List slicing is ntg but getting a part of the list

syntax: listname[start:stop:step]

ex: 
num = [10,20,30,40,50]
num[1:4]  # [20,30,40]
num[3:]  #40,50

ex2:
n = [1,2,[4,5,6],7]
n[2][1]  #5

# %% [markdown]
# # List Methods

# %% [raw]
# 1. Add items in list
# a. append() - adds one item at end
# ex:
# n = [1,2]
# n.append(3)
# n   # [1,2,3]
#
# b. insert() - adds at specific position
# ex:
# n.insert(1,15)   # [1,15,2,3]
#         position, Value u perfer
#
# c. extend() - adds multiple items in the end/ adds another list
# ex:
# n.extend([20,48]) # [1,15,2,3,20,48]
# n.extend([[6,7]]) # [1,15,2,3,20,48,[6,7]]
#          another list
#
#
# 2. Remove items from list
# a. remove() -  removes by value
# ex:
# n.remove(20)
#
# b. pop() - removes by index
# ex:
# n.pop(1)
# n.pop() # removes last value
#
# c. clear() - removes everything (remove all)
# ex:
# n.clear()
#
#
# 3. Change items in list
# ex:
# m = [1,2,3]
# n[1] = 9
# n #[1,9,3]
#
#
# 4. Join lists by concatenation (by using + operator)
# ex:
# a = [1,2,3]
# b = [4,5]
# c = a+b
# print(c) # [1,2,3,4,5]
#
#
# 5. Membership in list (in/not in)
# ex:
# n = [10,20,30]
# print(20 in n)  # True
# print(50 not in n) # True
# print(30 not in n) # false
#
#
# 6. Reverse list
# -- using reverse() # reverse entire list
# ex:
# n.reverse()
# -- using slicing
# ex:
# n1 = n[::-1]
#
#
# 7. Sort list
# -- ascending
# n = [40,10,50,20,35]
# n.sort()  #[10,20,35,40,50]
#
# -- descending
# n.sort(reverse=True) # [50,40,35,20,10]
#
#
# 8.count()
# -- count how many times that item appears in list
# ex:
# num = [1,2,3,1,4,2,1]
# num.count(1) #3
# num.count(4) #1
#
#
# 9. len()
# -- tells the length / no.of items in a list
# ex:
# len(num)  #7
# ex2:
# a = [1,2,[3,4,5]]
#      0 1  2
# len(a)  #3
#
#
# 10. copy()
# -- duplicate
# ex:
# a = [1,2,3,4]
# b = a.copy()
# b

# %% [markdown]
# # Tuple

# %% [raw]
# Tuple as just like a list (is a collection of items which is ordered and can be changed)
# but with one big rule - once a tuple is created we cannot change it (Immutable)
# -- all elements are stored in ()
#
# ex:
# roll no. list
# days of the week
# months in a year
#
# Syntax: tuplename = (value1,val2,val3,...,valuen)
#
# ex: t = (10,20,30)
#
# Properties:
# 1. Ordered : items have fixed positions
# 2. Immutable : we cannot modify values (unchangable)
# 3. Heterogeneous : can store diff datatypes (int,str,bool,float,etc..)
# 4. Allow duplicates : same value can repeat
# 5. Indexed : Each item has a number (position)
#
# Note: single value tuple
# t = (10,) #comma is compulsory
# type(t) # tuple
# t1 = (10) # not a tuple
# type(t1) # int

# %% [markdown]
# # Tuple indexing

# %% [raw]
# t = (10,20,30,40)
# t[0] #10
# t[3] #40
# t[-2] #30

# %% [markdown]
# # Tuple slicing

# %% [raw]
# t = (10,20,30,40,50)
# t[1:4] #(20,30,40)
# t[2:] #(30,40,50)
# t[:3] #(10,20,30)
# t[::-1] #reverse

# %% [markdown]
# # Tuple Methods

# %% [raw]
# -- only reading is allowed
# 1. count()
# t.count(10) #1
#
# 2. index()
# t.index(20) #1
# t.indedx(10) #0

# %% [markdown]
# # sorting tuple

# %% [raw]
# sorting tuple indirect method
# -- since tuple can't change
# -- we must convert it. convert to list first
# ex:
# t = (40,10,30,20)
# l = list(t)
# l.sort()
#
# t = tuple(l)
# print(t)

# %% [markdown]
# # Set

# %% [raw]
# Set is a collection of values where no duplicate values are allowed
# -- stores : only unique values, No fixed order, No duplicates
# -- all elements are stored in {} -- curly/flower brackets
#
# syntax: setname = {value1,val2,val3,...valn}
#
# ex:
# s = {10,20,30,20,40,10}
# print(s)  # {10,20,30,40} #duplicates removed automatically
#
# Properties:
# 1. Unordered - no fixed position  (No indexing, No slicing)
# 2. No indexing
# 3. No duplicates - repeated values removed
# 4. Mutable
# 5. Heterogeneous
#
# Note: empty set
# s = set()  #set
# s = {} #this creates a dictinory

# %% [markdown]
# # Set Methods

# %% [raw]
# 1. add() - add one value
# ex:
# s = {10,20,30}
# s.add(30)
# s
#
# 2. update() - add multiple values
# ex:
# s.update([40,50])
#
# 3.remove() - error if item not found
# s.remove(20)
# s.remove(100)
#
# 4. discard() - no error even if item not found
# s.discard(100)
#
# 5. pop() - removes random item  (bcoz no indexing)
# s.pop()
#
# 6. clear() - removes all items
# s.clear()

# %% [markdown]
# # Set Operations

# %% [raw]
# a = {1,2,3,4}
# b = {3,4,5,6}
# 1. union (|) -- all values (no repeat)
# print(a|b)  #{1,2,3,4,5,6}
#
# 2. intersection (&) -- common values
# print(a&b)
#
# 3. difference (-) -- a-b
# print(a-b)
#
# 4. symmetric difference (^) -- not common
# print(a^b)

# %% [markdown]
# # Dictionary

# %% [raw]
# Dictionary stores values in key:value format
# -- just like a real dictionary
# word = key
# meaning = value
#
# syntax: dictname = {key1:value1,key2:value2,...}
#
# ex: d = {"id":101,"name":"keerty"}
#
# Note : empty dic
# d = {} or d = dict()
#
# Properties:
# 1. Uses Key:Value
# 2. Keys are unique
# 3. Mutable
# 4. Unordered -- no fixed position
# 5. Heterogenous -- mixed datatypes (keys&values can be anytype)
#
# ex: d1 = {1:"One", 2:"Two", 3:"Three"}

# %% [raw]
# # Accessing values from dic
# -- we always access values using keys
# ex:
# e = {"name":"keerty","salary":20000,"dept":"DS"}
# e["name"]  # keerty
# e["salary"] #20000
#
# 1. all keys: e.keys()
# 2. all values: e.values()
# 3. all items: e.items()
#
#
# # removing data from dic
# 1. pop()
# e.pop("salary")
#
# 2. del
# del e["name"]
#
# 3. popitem() -- removes last item
# e.popitem()
#
# 4. clear()
# e.clear()
#
#
# # changing value
# e["salary" = 30000
#
#
# # adding new items
# e["city"] = "Hyd"

# %% [markdown]
# # String Methods

# %% [raw]
# 1. count() -- count how many times a word/letter repeates
# ex : a = "python programming"
#      a.count("p")  #2
#      a.count("python")  #1
#
# 2. startswith() -- check if string starts with a word/letter
# ex : a.startswith("p")  # True
#      a.startswith("P")  # False -- captial
#      a.startswith("pyt")  # True
#
# 3. endswith() -- check if string ends with a word/letter
# ex : a.endswith("ing") #True
#      a.endswith("programming") #True
#      a.endswith("on") #False
#
# 4. upper() -- convert to CAPTIAL letters
# ex : a.upper() #'PYTHON PRPGRAMMING'
#
# 5. lower() -- convert to small letters
# ex : a.lower()  #python programming
#
# 6. title() -- first letter of each word captial
# ex : a.title()  #'Python Programming'
#
# 7. capitalize() -- only first letter of the full string captial
# ex : a.capitalize() #Python programming'
#
# 8. replace() -- replace one word with another
# syntax : varname.replace(oldword, newword)
# ex : a.replace("python", "java")
#
# 9. split() -- convert string into a list
# ex : a.split() #['python','programming']
#
# 10. strip() -- remove extra spaces from both sides
# ex : "_hi_".strip()  --'hi'
#
# ** lstrip() -- removes left spaces
# ** rstrip() -- removes right spaces
#
# 11. find() -- find position of a word/letter (tells the starting index position of a given word)
# ex : a.find("pro")  #7
#      -- if the word is not found
#       ex : a.find("jai")  #-1
#
# 12. update & delete string -- cannot be changed (immutable)
#
# 13. string concatenation -- means joining 2 or more strings together
#     ** a+b -- joins
#     ** " " -- adds space b/w words
# ex : a = 'hello'
#      b = 'world'
#      print(a+" "+b)  #hello world
#
# 14. string partitioning -- it splits the string into 3 parts (partition() )
#                            1. Before the symbol (argument)
#                            2. The symbol itself
#                            3. After the symbol
# ex : n = "python_is_awesome"
#      n.partition("is")  #('python_','is','_awesome')
#
# 15. format() -- for string formatting -- used to insert values into a string neatly
# ex : name = "keerty"
#      age = 25
#      print("My name is {} and my age is {}".format(name,age))
#      # My name is keerty and my age is 25

# %% [markdown]
# # Loops

# %% [raw]
# Loops helps us to repeat tasks automatically without rewriting code again and again
# ex : Imagine I tell you to print Hello 100 times
#      will u write 100 print stmts?  (infinite & finite)
#
# 1. While Loop : runs as long as a condition is TRUE
# ex : cycle paddling, phone battery
# syntax : while condition:
#              stmt 1
#              stmt 2
#
# ex : DON'T EXECUTE
#      i = 1
#      while i<=5:
#          print(i)
#
# ex2: print "Hello" 3 times
# i = 1
# while i <= 3:
#     print("Hello")
#     i = i+1  #i+=1
#
# ex3: Take input until user enters 0
# num = int(input("Enter a number:"))
# while num != 0:
#     print("you entered",num)
#     num = int(input("Enter a number again:"))
# print("you entered 0, so the loop stopped")

# %% [raw]
# # Break
# -- stop the loop immediately, even if the condition is still TRUE,
# the loop will exit instantly
#
# syntax : while cond1:
#              if cond2:
#                  break
#              stmt
#
#
#
#
# ex1 : stop loop when num is 5
# i = 1
# while i<=20:
#     if i == 5:
#         break
#     print(i)
#     i = i+1
#
# o/p :
# 1
# 2
# 3
# 4
#
#
# # Continue
# -- skip the current step and go to the next one
# -- it doesnot stop the loop -- only skips one round
# syntax : while cond1:
#              if cond2:
#                  continue
#              stmt
#
# ex1 :
# i = 0
# while i<=10:
#     i+=1
#     if i==5:
#         continue
#     print(i)
#
# o/p:
# 1
# 2
# 3
# 4
# #no. 5 skip
# 6
# 7
# 8
# 9
# 10
#
# ex2 : Skip even numbers
# i = 1
# while i<=10:
#     i+=1
#     if i%2==0:
#         continue
#     print(i)

# %% [raw]
# # Membership Operators  -- in & not in
# These are used to check if a value exists in a sequence
# ex : print(3 in [1,2,3,4]) # True
#      print("a" not in "apple") # False

# %% [raw]
# # range(start,stop,step)
# -- range is used to generate a sequence of numbers
# ** start : where to begin
# ** stop : where to stop
# ** step : jump value
# ex : print(* range(5))  # * star operator
# o/p : 0 1 2 3 4  #to get clean o/p
#
# ex1: print(range(1,6))
# o/p : range(1,6)
#
# ex2: print(list(range(1,6)))
# o/p : [1, 2, 3, 4, 5]

# %% [raw]
# 2. For Loop
# -- is used to repeat something for each item in a group
#
# ex : Take attendance, every std in the class one by one
# syntax: for variable in sequence:
#              stmts
#
# ex1 : using for with range()
# for i in range(1,6):
#     print(i)
# o/p :
# 1
# 2
# 3
# 4
# 5
#
# ex2 : for loop with list
# num = [1,2,3,4]
# for n in num:
#     print(n)
# o/p :
# 1
# 2
# 3
# 4
#
# ex3 : for loop with string
# for i in "keerty":
#     print(i)
# o/p :
# k
# e
# e
# r
# t
# y
#
# ex4 : for loop with string
# for i in "keerty":
#     print(i,end="")
# o/p : keerty
#
# ex5 : Table program
# n = 5
# for i in range(1,11):
#     print(n,'X',i,'=',n*i)
# o/p:
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
# 5 X 10 = 50
#
# ex6 : continue in for loop
# for i in range(1,6):
#     if i == 3:
#         continue
#     print(i)
# o/p:
# 1
# 2
# 4
# 5
#
# ex7: check which is even and which is odd
# l = [2,43,7,24,3,8]
# for i in l:
#     if i%2 == 0:
#         print(i,"is even")
#     else:
#         print(i,"is odd")
# o/p:
# 2 is even
# 43 is odd
# 7 is odd
# 24 is even
# 3 is odd
# 8 is even

# %% [raw]
# for -- I know the count (when you know how many times to repeat)
# while -- I only know the condition (when u don't know how many times to repeat)
